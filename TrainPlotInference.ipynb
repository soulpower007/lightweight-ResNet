# %%
# Import the required libraries.
import os
import shutil

# Clone the repository.
# !git clone https://github.com/soulpower007/lightweight-ResNet.git

# Copy the files from the repository to the current working directory.
# Out:
# Cloning into 'lightweight-ResNet'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 86 (delta 43), reused 49 (delta 15), pack-reused 0
# Receiving objects: 100% (86/86), 16.76 MiB | 24.21 MiB/s, done.
# Resolving deltas: 100% (43/43), done.

# %%
os.chdir('lightweight-ResNet')

# %%
# !python main.py --arch 4 4 3 --ch 64 --ks 3 --lr 0.05 --bs 256
# Out:
# Starting experiment 1.
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Number of parameters: 4,697,162
# Training epoch: 0:   0% 0/196 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Training epoch: 0: 100% 196/196 [00:45<00:00,  4.34it/s, acc=0.377, loss=1.68]
# ...

# %%
## we have stopped the above running script because we already ran it on hpc
## below we can run the plotting code

# %%
#Stored the model in logs/1 hence we run the below code

# !python plot_logs.py --id 1

# %%
from IPython.display import Image
image = Image(filename='/content/lightweight-ResNet/logs.png')
display(image)

# %%
# !python inference.py --id 1
